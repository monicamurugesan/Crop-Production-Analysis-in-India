# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
datacrop=pd.read_csv("Crop Production Data.csv")

# %%
datacrop
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# ...

# %%
datacrop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
datacrop.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
'''
d1=datacrop.dropna()



d1.info()


d1.describe()


d1.shape



d1.isnull().sum()

'''
# Out:
# '\nd1=datacrop.dropna()\n\n\n\nd1.info()\n\n\nd1.describe()\n\n\nd1.shape\n\n\n\nd1.isnull().sum()\n\n'

# %%
datacrop['Production']=datacrop['Production'].fillna(datacrop['Production'].mean())

# %%
datacrop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     246091 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
datacrop.shape
# Out:
# (246091, 7)

# %%
import seaborn as sns
sns.heatmap(datacrop.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
datacrop.State_Name.nunique()
# Out:
# 33

# %%
datacrop.State_Name.unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir ', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana ',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
datacrop.District_Name.nunique()
# Out:
# 646

# %%
datacrop.District_Name.unique()
# Out:
# array(['NICOBARS', 'NORTH AND MIDDLE ANDAMAN', 'SOUTH ANDAMANS',
#        'ANANTAPUR', 'CHITTOOR', 'EAST GODAVARI', 'GUNTUR', 'KADAPA',
#        'KRISHNA', 'KURNOOL', 'PRAKASAM', 'SPSR NELLORE', 'SRIKAKULAM',
#        'VISAKHAPATANAM', 'VIZIANAGARAM', 'WEST GODAVARI', 'ANJAW',
#        'CHANGLANG', 'DIBANG VALLEY', 'EAST KAMENG', 'EAST SIANG',
#        'KURUNG KUMEY', 'LOHIT', 'LONGDING', 'LOWER DIBANG VALLEY',
#        'LOWER SUBANSIRI', 'NAMSAI', 'PAPUM PARE', 'TAWANG', 'TIRAP',
#        'UPPER SIANG', 'UPPER SUBANSIRI', 'WEST KAMENG', 'WEST SIANG',
#        'BAKSA', 'BARPETA', 'BONGAIGAON', 'CACHAR', 'CHIRANG', 'DARRANG',
#        'DHEMAJI', 'DHUBRI', 'DIBRUGARH', 'DIMA HASAO', 'GOALPARA',
#        'GOLAGHAT', 'HAILAKANDI', 'JORHAT', 'KAMRUP', 'KAMRUP METRO',
#        'KARBI ANGLONG', 'KARIMGANJ', 'KOKRAJHAR', 'LAKHIMPUR', 'MARIGAON',
#        'NAGAON', 'NALBARI', 'SIVASAGAR', 'SONITPUR', 'TINSUKIA',
#        'UDALGURI', 'ARARIA', 'ARWAL', 'AURANGABAD', 'BANKA', 'BEGUSARAI',
# ...

# %%
datacrop.Crop.nunique()
# Out:
# 124

# %%
datacrop.Crop.unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut ', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram',
#        'Jowar', 'Korra', 'Ragi', 'Tobacco', 'Gram', 'Wheat', 'Masoor',
#        'Sesamum', 'Linseed', 'Safflower', 'Onion', 'other misc. pulses',
#        'Samai', 'Small millets', 'Coriander', 'Potato',
#        'Other  Rabi pulses', 'Soyabean', 'Beans & Mutter(Vegetable)',
#        'Bhindi', 'Brinjal', 'Citrus Fruit', 'Cucumber', 'Grapes', 'Mango',
#        'Orange', 'other fibres', 'Other Fresh Fruits', 'Other Vegetables',
#        'Papaya', 'Pome Fruit', 'Tomato', 'Rapeseed &Mustard', 'Mesta',
#        'Cowpea(Lobia)', 'Lemon', 'Pome Granet', 'Sapota', 'Cabbage',
# ...

# %%
datacrop.Crop_Year.nunique()
# Out:
# 19

# %%
datacrop.Season.unique()
# Out:
# array(['Kharif     ', 'Whole Year ', 'Autumn     ', 'Rabi       ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
datacrop.Season.nunique()
# Out:
# 6

# %%
datacrop.Area.nunique()
# Out:
# 38442

# %%
datacrop.Production.nunique()
# Out:
# 51628

# %%
datacrop.groupby(['Season','District_Name','State_Name'])['Crop'].count()
# Out:
# Season       District_Name       State_Name
# Autumn       24 PARAGANAS NORTH  West Bengal    24
#              24 PARAGANAS SOUTH  West Bengal    21
#              AHMEDNAGAR          Maharashtra     1
#              ALAPPUZHA           Kerala         17
#              ANUGUL              Odisha         99
#                                                 ..
# Winter       WEST GARO HILLS     Meghalaya      12
#              WEST JAINTIA HILLS  Meghalaya       2
#              WEST KHASI HILLS    Meghalaya      12
#              WEST SINGHBHUM      Jharkhand       8
#              YANAM               Puducherry      2
# Name: Crop, Length: 2573, dtype: int64

# %%
d2=datacrop.groupby('Season')['Crop'].count()

d2.plot(kind='pie',figsize=(20,20),autopct="%1.1f")
# Out:
# <AxesSubplot:ylabel='Crop'>

# %%
d3=datacrop.groupby(['Crop'])['Production'].count()

# %%
d3
d3.plot(kind='bar',figsize=(30,30),label='Crop')
# Out:
# <AxesSubplot:xlabel='Crop'>

# %%
d4=datacrop.groupby('Crop_Year')[['State_Name','Production']].sum()
d4.plot.bar()
# Out:
# <AxesSubplot:xlabel='Crop_Year'>

# %%
cereals=['Rice','Maize','Wheat','Barley','Varagu','Other Cereals & Millets','Ragi','Small millets','Bajra','Jowar', 'Paddy','Total foodgrain','Jobster']
pulses=['Moong','Urad','Arhar/Tur','Peas & beans','Masoor',
              'Other Kharif pulses','other misc. pulses','Ricebean (nagadal)',
              'Rajmash Kholar','Lentil','Samai','Blackgram','Korra','Cowpea(Lobia)',
              'Other  Rabi pulses','Other Kharif pulses','Peas & beans (Pulses)','Pulses total','Gram']
veg=['Turnip','Peas','Beet Root','Carrot','Yam','Ribed Guard','Ash Gourd ','Pump Kin','Redish','Snak Guard','Bottle Gourd',
              'Bitter Gourd','Cucumber','Drum Stick','Cauliflower','Beans & Mutter(Vegetable)','Cabbage',
              'Bhindi','Tomato','Brinjal','Khesari','Sweet potato','Potato','Onion','Tapioca','Colocosia']
spices=['Perilla','Ginger','Cardamom','Black pepper','Dry ginger','Garlic','Coriander','Turmeric','Dry chillies','Cond-spcs other']
fibres=['other fibres','Kapas','Jute & mesta','Jute','Mesta','Cotton(lint)','Sannhamp']
nuts=['Arcanut (Processed)','Atcanut (Raw)','Cashewnut Processed','Cashewnut Raw','Cashewnut','Arecanut','Groundnut']
oilseeds=['other oilseeds','Safflower','Niger seed','Castor seed','Linseed','Sunflower','Rapeseed &Mustard','Sesamum','Oilseeds total']
com=['Tobacco','Coffee','Tea','Sugarcane','Rubber']
fruits=['Peach','Apple','Litchi','Pear','Plums','Ber','Sapota','Lemon','Pome Granet',
               'Other Citrus Fruit','Water Melon','Jack Fruit','Grapes','Pineapple','Orange',
               'Pome Fruit','Citrus Fruit','Other Fresh Fruits','Mango','Papaya','Coconut','Banana']

def cat_crop(crop):
    for i in cereals:
        if crop==i:
            return 'Cereals'
    for i in pulses:
        if crop==i:
            return 'Pulses'
    for i in fruits:
        if crop==i:
            return 'Fruits'
    for i in veg:
        if crop==i:
            return 'veg'
    for i in spices:
        if crop==i:
            return 'spices'
    for i in fibres:
        if crop==i:
            return 'fibres'
    for i in nuts:
        if crop==i:
            return 'nuts'
    for i in oilseeds:
        if crop==i:
            return 'oilseeds'
    for i in com:
        if crop==i:
            return 'com'
datacrop['cat_crop']=datacrop['Crop'].apply(cat_crop)

# %%
datacrop
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production  cat_crop
# ...

# %%
d5=datacrop.groupby('cat_crop')['State_Name'].count()
d5.plot.bar()
# Out:
# <AxesSubplot:xlabel='cat_crop'>

# %%
datacrop.groupby('cat_crop')['State_Name'].max()
# Out:
# cat_crop
# Cereals       West Bengal
# Fruits      Uttar Pradesh
# Pulses        West Bengal
# com           West Bengal
# fibres        West Bengal
# nuts          West Bengal
# oilseeds      West Bengal
# spices        West Bengal
# veg           West Bengal
# Name: State_Name, dtype: object

# %%
d5.plot.pie(radius=3,autopct="%1.1f",pctdistance=0.6)
# Out:
# <AxesSubplot:ylabel='State_Name'>

# %%
d6=datacrop.groupby('cat_crop')['Production'].count()
d6.plot.bar()
# Out:
# <AxesSubplot:xlabel='cat_crop'>

# %%
d7=datacrop.groupby('District_Name')['Production'].sum()
d7[:10].plot.bar(figsize=(30,30))
# Out:
# <AxesSubplot:xlabel='District_Name'>

# %%
datacrop.groupby('District_Name')[['State_Name','Production']].max()
# Out:
#                         State_Name    Production
# District_Name
# 24 PARAGANAS NORTH     West Bengal  7.509500e+07
# 24 PARAGANAS SOUTH     West Bengal  5.310000e+07
# ADILABAD                Telangana   6.595200e+05
# AGAR MALWA          Madhya Pradesh  9.150200e+04
# AGRA                 Uttar Pradesh  1.836400e+06
# ...                            ...           ...
# YADGIR                   Karnataka  5.825034e+05
# YAMUNANAGAR                Haryana  2.894000e+06
# YANAM                   Puducherry  5.641000e+06
# YAVATMAL               Maharashtra  9.814000e+05
# ZUNHEBOTO                 Nagaland  5.825034e+05
#
# [646 rows x 2 columns]

# %%
df11=datacrop.groupby(['cat_crop','Crop_Year'])['Production'].count()
df11.plot(figsize=(30,30))
# Out:
# <AxesSubplot:xlabel='cat_crop,Crop_Year'>

# %% [markdown]
# Highest Production of Cereals happened in 1997,then fruits production was peaked in 2003, 2010 pulses production got increased along with other crops production

# %%
plt.figure(figsize=(30,30))
sns.barplot(datacrop['Production'],datacrop['State_Name'],orient='h',label=datacrop['Production'])
# Out:
# C:\Users\MONIKA\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Production', ylabel='State_Name'>

# %%
dj=datacrop['Crop'].value_counts()
dj[:50].plot.bar()
# Out:
# <AxesSubplot:>

# %%
dj
# Out:
# Rice                 15104
# Maize                13947
# Moong(Green Gram)    10318
# Urad                  9850
# Sesamum               9046
#                      ...
# Litchi                   6
# Coffee                   6
# Apple                    4
# Peach                    4
# Other Dry Fruit          1
# Name: Crop, Length: 124, dtype: int64

# %%
dj.min()
# Out:
# 1

# %%
datarice=datacrop[datacrop['Crop']=='Rice']
datarice
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 12      Andaman and Nicobar Islands      NICOBARS       2001  Kharif
# 18      Andaman and Nicobar Islands      NICOBARS       2002  Kharif
# 27      Andaman and Nicobar Islands      NICOBARS       2003  Kharif
# 36      Andaman and Nicobar Islands      NICOBARS       2004  Kharif
# ...                             ...           ...        ...          ...
# 246049                  West Bengal       PURULIA       2013  Summer
# 246052                  West Bengal       PURULIA       2013  Winter
# 246058                  West Bengal       PURULIA       2014  Autumn
# 246086                  West Bengal       PURULIA       2014  Summer
# 246089                  West Bengal       PURULIA       2014  Winter
#
#         Crop       Area  Production cat_crop
# 2       Rice     102.00      321.00  Cereals
# ...

# %%
datar1=datarice.groupby('Season')['Production'].count()
datar1.plot.bar()
# Out:
# <AxesSubplot:xlabel='Season'>

# %%
plt.figure(figsize=(13,10))
sns.barplot("State_Name","Production",data=datarice)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\MONIKA\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
datacrop[datacrop['Crop']=="Other Dry Fruit"]
# Out:
#         State_Name District_Name  Crop_Year       Season             Crop  \
# 195884  Telangana     RANGAREDDI       2003  Whole Year   Other Dry Fruit
#
#         Area  Production cat_crop
# 195884   7.0         0.0     None

# %%
os1=datacrop[datacrop['Crop']=='other oilseeds']

# %%
osg1=os1.groupby(['State_Name','Season'])['Production'].count()
osg1.plot.bar()
# Out:
# <AxesSubplot:xlabel='State_Name,Season'>

# %%
osg2=os1.groupby(['District_Name','Season'])['Production'].count()
osg2[:10].plot.bar()
# Out:
# <AxesSubplot:xlabel='District_Name,Season'>

# %% [markdown]
# Punjab and Kerala are top producers of rice
# Rajasthan is the top producer of oilseeds

# %%
fruits=datacrop[datacrop['cat_crop']=='Fruits']

# %%
fruits
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 20      Andaman and Nicobar Islands      NICOBARS       2002  Whole Year
# 29      Andaman and Nicobar Islands      NICOBARS       2003  Whole Year
# 38      Andaman and Nicobar Islands      NICOBARS       2004  Whole Year
# 47      Andaman and Nicobar Islands      NICOBARS       2005  Whole Year
# ...                             ...           ...        ...          ...
# 230597                Uttar Pradesh     SULTANPUR       2014  Summer
# 230814                Uttar Pradesh         UNNAO       2004  Whole Year
# 230870                Uttar Pradesh         UNNAO       2006  Whole Year
# 231090                Uttar Pradesh         UNNAO       2013  Summer
# 231123                Uttar Pradesh         UNNAO       2014  Summer
#
#           Crop    Area  Production cat_crop
# 3       Banana  176.00      641.00   Fruits
# ...

# %%
frut21=fruits.groupby(['Crop'])['State_Name'].count()
frut21.plot.bar()
# Out:
# <AxesSubplot:xlabel='Crop'>

# %%
frut1=fruits.groupby(['Crop','State_Name'])['Production'].count()
frut1[:5].plot.bar()
# Out:
# <AxesSubplot:xlabel='Crop,State_Name'>

# %% [markdown]
# Assam used to be the top producer of banana
